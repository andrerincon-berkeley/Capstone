# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# %%
raw_data_path = '../data/raw_data/els_02/els_02_12_byf3pststu_v1_0.csv'
n_rows = 5000

# Read first 5000 rows
df_sample = pd.read_csv(raw_data_path, nrows=n_rows)

df_sample.head()
# Out:
# C:\Users\james\AppData\Local\Temp\ipykernel_8716\475462405.py:5: DtypeWarning: Columns (1222) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_sample = pd.read_csv(raw_data_path, nrows=n_rows)
#    STU_ID  SCH_ID  STRAT_ID  PSU  F1SCH_ID  F1UNIV1  F1UNIV2A  F1UNIV2B  \
# 0  101101      -5       101    1      1011      101         1         1
# 1  101102      -5       101    1      1011      101         1         1
# 2  101104      -5       101    1      1011      101         1         1
# 3  101105      -5       101    1      1011      101         1         1
# 4  101106      -5       101    1      1011      101         1         1
#
#    F2UNIV1  F2UNIV_P  ...  BYF10D  BYF10E  BYF10F  BYF10G  BYF10H  BYF10I  \
# 0       -5       103  ...       0       1       1       1       1       1
# 1       -5       101  ...       0       1       1       1       1       1
# 2       -5       101  ...       0       1       1       1       1       1
# ...

# %%
view_cols = ['STU_ID','F1UNIV1','F1UNIV2A','F2UNIV_P','BYSEX','BYRACE','BYSTLANG','BYHOMLNG','BYPARED','BYINCOME',
            'BYSES1','BYSES1QU','BYSES2','BYSES2QU','BYGRDRPT','BYLGRRPT','BYRISKFC','BYSTEXP','BYPARASP','BYOCCHS',
            'BYOCC30','BYSCHPRG','BYTXCSTD','BYTXCQU','BYNELS2M','BYNELS2R','BYNELS0M','BYPISAME','BYPISARE','BYTXMIRR',
            'BYTXMSTD','BYTXMQU','BYTX1MPP','BYTX2MPP','BYTX3MPP','BYTX4MPP','BYTX5MPP','BYTXRIRR','BYTXRSTD','BYTXRQU',
            'BYTX1RPP','BYTX2RPP','BYTX3RPP','BYMATHSE','BYENGLSE','BYCONEXP','BYINSTMO','BYACTCTL','BYSTPREP','BYWRTNGA',
            'BYHISPOR','BYNSPORT','BYXTRACU','BYHMWRK','BYTVVIGM','BYWORKSY','BYWRKHRS','BYG10EP','BYSCENP','BYSCTRL',
            'BYURBAN','BYREGION','BYREGURB','BY10FLP','BYACCLIM','BYINCMIM','F1SEX','F1RACE','F1STLANG','F1DOB_P',
            'F1FCOMP','F1SES1','F1SES1QU','F1SES2','F1SES2QU','F1STEXP','F1BYEDEX','F1OCC30','F1DOSTAT','F1GRADE',
            'F1TXMBIR','F1TXM1IR','F1TXMSTD','F1TXMQU','F1NELS2M','F1TX1MPP','F1TX2MPP','F1TX3MPP','F1TX4MPP','F1TX5MPP',
            'F1BYMTGN','F1HIMATH','F1PSEPLN','F1XTRACU','F1WRKHRS','F1TVVIGM','F1COLINF','F1MATHSE','F1RHTUNP','F1RMAT_P',
            'F1RGPP2','F2EVERDO','F2DOSTAT','F2F1GR_P','F2HSSTAT','F2F1HSST','F2HSATTM','F2EDLEVL','F2HIGRDE','F2HSCPP2',
            'F2PSEEXM','F2EVRAPP','F2NAPP1P','F2NAPP2P','F2NACC1P','F2NACC2P','F2NAPAID','F2NATT_P','F2PS1LVL','F2PS1CTR',
            'F2PS1SEC','F2PS1GRT','F2PS1LN','F2PS1WKS','F2PS1WVR','F2PS1AID','F2PS1NTY','F2PS1FTP','F2PS1OUT','F2PS1EEX',
            'F2PS1REM','F2ENRGAP','F2SWITCH','F2PS2006','F2MJR2_P','F2STEXP','F2CURWGE','F2QXDATP','F3NRSTAT','F3QDATE',
            'F3JUNEDSTAT','F3EVRATT','F3EDSTAT','F3PS1OUT','F3PS1RETAIN','F3PSLLVL','F3PSLCTR','F3PSLSEC','F3PSLCRED','F3PS2BA',
            'F3NATTND','F3NUMPUB','F3NUMMOD4','F3PSSELECT','F3ATTAINMENT','F3F1EDEXPFF','F3STEXP','F3EMPSTAT','F3ONET2CURR','F3SEICURR',
            'F3SPERN2011','F3STLOANEVR','F3STLOANAMT','F3JOBSATIS','F3SES','F3SESQU','F3REGION','F3CNSDUE','F3TZDEG1SEC','F3TZDEG1SLC',
            'F3TZBCH1CIP2','F3TZBCHLCIP2','F3TZSTEM1CRED','F3TZPS2BA','F3TZGPAALL','BYS20J','BYS23A','BYS23C','BYS24C','BYS27D',
            'BYS55B','BYS55C','BYS59A','BYS59B','BYS59C','BYS59D','BYS59E','BYS59F','BYS59G','BYS59H',
            'BYS59I','BYS59J','BYS62A','BYS62B','BYS62D','BYS62E','BYS62G','BYS62H','F1S48A','F1S48B',
            'F1S48C','F1S48D','F1S48E','F1S48F','F1S48G','F1S48H','F1S48I','F1S48J','F1S48K','F1S48L',
            'F1S48M','F1S48N','F1S52A','F1S52B','F1S52F','F1S52I','F1S52K','F1S52L','F1S55A'
            ]

df_sample[view_cols].head()
# Out:
#    STU_ID  F1UNIV1  F1UNIV2A  F2UNIV_P  BYSEX  BYRACE  BYSTLANG  BYHOMLNG  \
# 0  101101      101         1       103      2       5         1         1
# 1  101102      101         1       101      2       2         0         4
# 2  101104      101         1       101      2       7         1         1
# 3  101105      101         1       101      2       3         1         1
# 4  101106      101         1       101      2       4         0         2
#
#    BYPARED  BYINCOME  ...  F1S48L  F1S48M  F1S48N  F1S52A  F1S52B  F1S52F  \
# 0        5        10  ...      -3      -3      -3      -3      -3      -3
# 1        5        11  ...       0       0       0       2       2       2
# 2        2        10  ...       0       0       0       2       3       1
# 3        2         2  ...       0       0       0       2       3       3
# 4        1         6  ...       0       1       0       2       3       3
#
#    F1S52I  F1S52K  F1S52L  F1S55A
# 0      -3      -3      -3      -3
# ...

# %%
# Clean the data by removing negative values (missing data codes)
clean_df = df_sample[
    (df_sample['X1FAMINCOME'] >= 0) & 
    (df_sample['X5SRRESP'] >= 0)
]

# Create the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(clean_df['X1FAMINCOME'], clean_df['X5SRRESP'], alpha=0.5)
plt.xlabel('Family Income (X1FAMINCOME)')
plt.ylabel('X5SRRESP')
plt.title('Family Income vs X5SRRESP')

# Add grid for better readability
plt.grid(True, linestyle='--', alpha=0.7)

plt.show()

# %%
# Create a cross-tabulation of BYSES1QU and F3PSLCRED
crosstab = pd.crosstab(df_sample['BYSES1QU'], df_sample['F1RGPP2'])

# Create a grouped bar chart
ax = crosstab.plot(kind='bar', figsize=(12, 6))

# Customize the chart
plt.title('Distribution of Postsecondary Credits by SES Quartile')
plt.xlabel('SES Quartile (BYSES1QU)')
plt.ylabel('Count of Students')
plt.legend(title='Postsecondary Credits\n(F1RGPP2)', bbox_to_anchor=(1.05, 1))

# Rotate x-axis labels for better readability
plt.xticks(rotation=0)

# Add grid for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adjust layout to prevent label cutoff
plt.tight_layout()

plt.show()

# %%
df_full = pd.read_csv(raw_data_path)
df_full.shape
# Out:
# C:\Users\james\AppData\Local\Temp\ipykernel_8716\86728721.py:1: DtypeWarning: Columns (1222) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_full = pd.read_csv(raw_data_path)
# (16197, 4012)

# %%
# Calculate the percentage of valid values for each column
def get_valid_percentage(series):
    if pd.api.types.is_numeric_dtype(series):
        return (series >= 0).mean()
    else:
        # For non-numeric columns, consider them valid (return 1.0)
        return 1.0

# Apply the function to each column
valid_percentages = df_full.apply(get_valid_percentage)

# Get columns where at least 50% of values are valid
columns_50pct_valid = valid_percentages[valid_percentages >= 0.5].index.tolist()

print(f"Found {len(columns_50pct_valid)} columns with >= 50% valid values")
print("\nFirst 10 columns:")
print(columns_50pct_valid[:10])
# Out:
# Found 2159 columns with >= 50% valid values
#
# First 10 columns:
# ['STU_ID', 'STRAT_ID', 'PSU', 'F1SCH_ID', 'F1UNIV1', 'F1UNIV2A', 'F1UNIV2B', 'F2UNIV_P', 'F3UNIV', 'F3UNIVG10']

# %%
# Get descriptions for first 10 columns with >= 50% valid values
first_10_cols = columns_50pct_valid[:10]

# Create a DataFrame with column descriptions
summary_df = pd.DataFrame({
    'Column': first_10_cols,
    'Data Type': df_full[first_10_cols].dtypes,
    'Non-Null Count': df_full[first_10_cols].count(),
    'Valid %': [valid_percentages[col] * 100 for col in first_10_cols],
    'Unique Values': [df_full[col].nunique() for col in first_10_cols]
})

# Display the summary
print("Summary of first 10 columns with >= 50% valid values:\n")
print(summary_df.to_string())
# Out:
# Summary of first 10 columns with >= 50% valid values:
#
#               Column Data Type  Non-Null Count    Valid %  Unique Values
# STU_ID        STU_ID     int64           16197  100.00000          16197
# STRAT_ID    STRAT_ID     int64           16197  100.00000            361
# PSU              PSU     int64           16197  100.00000              3
# F1SCH_ID    F1SCH_ID     int64           16197   76.42156            752
# F1UNIV1      F1UNIV1     int64           16197  100.00000             25
# F1UNIV2A    F1UNIV2A     int64           16197  100.00000              4
# F1UNIV2B    F1UNIV2B     int64           16197  100.00000              7
# F2UNIV_P    F2UNIV_P     int64           16197  100.00000             19
# F3UNIV        F3UNIV     int64           16197  100.00000             15
# F3UNIVG10  F3UNIVG10     int64           16197  100.00000             16

# %%
file_layout_data_path = '../data/raw_data/els_02/RecordFileLayout_ELS_02_12_BYF3PSTSTU.PRI.txt'

# Read the record layout file
with open(file_layout_data_path, "r") as f:
    # Skip first 22 lines
    for _ in range(22):
        next(f)
        
    # Initialize lists to store the fields
    field_names = []
    locations = []
    descriptions = []
    
    # Read lines until line 4034
    for line in f:
        if len(field_names) >= 4012:  # 4034 - 23 + 1
            break
            
        # Extract fields based on fixed positions
        field_name = line[:15].strip()
        location = line[15:29].strip()
        description = line[29:].strip()
        
        if field_name:  # Only add if field_name is not empty
            field_names.append(field_name)
            locations.append(location) 
            descriptions.append(description)

# Create DataFrame with the extracted fields            
layout_df = pd.DataFrame({
    'field_name': field_names,
    'location': locations, 
    'description': descriptions
})

# Display first few rows
print("First few rows of the record layout:")
print(layout_df.head())
# Out:
# First few rows of the record layout:
#   field_name location                     description
# 0     STU_ID      1-7                      Student ID
# 1     SCH_ID     7-11                       School ID
# 2   STRAT_ID    11-14                         Stratum
# 3        PSU    14-16           Primary sampling unit
# 4   F1SCH_ID    16-20  Link to first follow-up school

# %%
# Filter layout_df to only show records where field_name is in columns_50pct_valid
valid_fields_layout = layout_df[layout_df['field_name'].isin(columns_50pct_valid)]

print("\nRecord layout details for columns with >= 50% valid values:")
print(valid_fields_layout.to_string())

# Save the valid fields layout to CSV with fixed width formatting
output_path = '../data/raw_data/els_02/valid_fields_layout.csv'

# Format each row with fixed widths before saving
formatted_rows = []
for _, row in valid_fields_layout.iterrows():
    field_name = f"{row['field_name']:<15}"  # Left align, 15 chars
    location = f"{row['location']:<14}"      # Left align, 14 chars (starts at 16)
    description = row['description']         # Rest of line (starts at 30)
    formatted_rows.append(f"{field_name}{location}{description}")

# Write formatted rows to file
with open(output_path, 'w') as f:
    f.write('\n'.join(formatted_rows))

print(f"\nSaved valid fields layout to: {output_path}")
# Out:
# Record layout details for columns with >= 50% valid values:
#           field_name     location                                                                                                        description
# 0             STU_ID          1-7                                                                                                         Student ID
# 2           STRAT_ID        11-14                                                                                                            Stratum
# 3                PSU        14-16                                                                                              Primary sampling unit
# 4           F1SCH_ID        16-20                                                                                     Link to first follow-up school
# 5            F1UNIV1        20-23                                                                           Sample member status in BY and F1 rounds
# ...

# %%
# Create a cross-tabulation of BYSES1QU and F3PSLCRED
crosstab = pd.crosstab(df_full['BYSES1QU'], df_full['F2PS1LVL'])

# Create a grouped bar chart
ax = crosstab.plot(kind='bar', figsize=(12, 6))

# Customize the chart
plt.title('Distribution of Postsecondary Credits by SES Quartile')
plt.xlabel('SES Quartile (BYSES1QU)')
plt.ylabel('Count of Students')
plt.legend(title='Postsecondary Credits\n(F2PS1LVL)', bbox_to_anchor=(1.05, 1))

# Rotate x-axis labels for better readability
plt.xticks(rotation=0)

# Add grid for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adjust layout to prevent label cutoff
plt.tight_layout()

plt.show()

# %%
# Create a box plot to show distribution of math scores by SES quartile
plt.figure(figsize=(12, 6))

# Group data by BYSES1QU and get F1TXMSTD values for each group
data = [df_full[df_full['BYSES1QU'] == q]['F1TXMSTD'] for q in sorted(df_full['BYSES1QU'].unique()) if q >= 0]
labels = [str(q) for q in sorted(df_full['BYSES1QU'].unique()) if q >= 0]

plt.boxplot(data, labels=labels)

# Customize the chart
plt.title('Distribution of Math Scores by SES Quartile')
plt.xlabel('SES Quartile (BYSES1QU)')
plt.ylabel('Math Score (F1TXMSTD)')

# Add grid for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adjust layout
plt.tight_layout()

plt.show()
# Out:
# C:\Users\james\AppData\Local\Temp\ipykernel_49428\1769741040.py:8: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=labels)

# %%
# Create a cross-tabulation of BYSES1QU and F3PSLCRED
crosstab = pd.crosstab(df_full['BYSES1QU'], df_full['F2PS1EEX'])

# Create a grouped bar chart
ax = crosstab.plot(kind='bar', figsize=(12, 6))

# Customize the chart
plt.title('Distribution of Postsecondary Credits by SES Quartile')
plt.xlabel('SES Quartile (BYSES1QU)')
plt.ylabel('Count of Students')
plt.legend(title='Postsecondary Credits\n(F2PS1EEX)', bbox_to_anchor=(1.05, 1))

# Rotate x-axis labels for better readability
plt.xticks(rotation=0)

# Add grid for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adjust layout to prevent label cutoff
plt.tight_layout()

plt.show()

# %%
high_gpa_df = df_full[df_full['F1RGPP2'] == 6]

# Create a cross-tabulation of BYSES1QU and F3PSLCRED
crosstab = pd.crosstab(high_gpa_df['BYSES1QU'], high_gpa_df['F2PS1EEX'])

# Create a grouped bar chart
ax = crosstab.plot(kind='bar', figsize=(12, 6))

# Customize the chart
plt.title('Distribution of Postsecondary Credits by SES Quartile')
plt.xlabel('SES Quartile (BYSES1QU)')
plt.ylabel('Count of Students')
plt.legend(title='Postsecondary Credits\n(F2PS1EEX)', bbox_to_anchor=(1.05, 1))

# Rotate x-axis labels for better readability
plt.xticks(rotation=0)

# Add grid for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adjust layout to prevent label cutoff
plt.tight_layout()

plt.show()

# %%
high_gpa_df = df_full[df_full['F1RGPP2'] == 6]

# Create a cross-tabulation of BYSES1QU and F3PSLCRED
crosstab = pd.crosstab(high_gpa_df['BYSES1QU'], high_gpa_df['F2PS1EEX'], normalize='index')

# Create a grouped bar chart
ax = crosstab.plot(kind='bar', figsize=(12, 6))

# Customize the chart
plt.title('Distribution of Postsecondary Credits by SES Quartile')
plt.xlabel('SES Quartile (BYSES1QU)')
plt.ylabel('Percent of Students')
plt.legend(title='Relative average scores\n(F2PS1EEX)', bbox_to_anchor=(1.05, 1))

# Rotate x-axis labels for better readability
plt.xticks(rotation=0)

# Add grid for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adjust layout to prevent label cutoff
plt.tight_layout()

plt.show()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Create ps_selectivity field based on F3PSSELECT values
df_full['ps_selectivity'] = df_full['F3PSSELECT'].apply(lambda x: 3 if x >= 3 else (-1 if x < 0 else x))


# Create a cross-tabulation of F1RGPP2 (High School GPA) and ps_selectivity (Postsecondary Selective)
crosstab = pd.crosstab(df_full['F1RGPP2'], df_full['ps_selectivity'], normalize='index')

# Create a grouped bar chart
ax = crosstab.plot(kind='bar', figsize=(12, 6))

# Customize the chart
plt.title('Distribution of Postsecondary Selective by High School GPA')
plt.xlabel('High School GPA (F1RGPP2)')
plt.ylabel('Percent of Students')
plt.legend(title='Postsecondary Selective\n(ps_selectivity)', bbox_to_anchor=(1.05, 1))

# Rotate x-axis labels for better readability
plt.xticks(rotation=0)

# Add grid for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adjust layout to prevent label cutoff
plt.tight_layout()

plt.show()

# %%
# Count records where ps_selectivity is 3 (highly selective) and F1RGPP2 is 6 (highest GPA)
count = len(df_full[(df_full['ps_selectivity'] == 3) & (df_full['F1RGPP2'] == 6)])
print(f"Number of students with highest GPA (F1RGPP2=6) who attended highly selective institutions: {count}")
# Out:
# Number of students with highest GPA (F1RGPP2=6) who attended highly selective institutions: 311
